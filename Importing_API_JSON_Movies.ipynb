# %% [markdown]
# # Project 2: Data Import - Working with Web APIs and JSON (Movies Dataset)

# %% [markdown]
# ## Importing Data from JSON files

# %%
import pandas as pd
import json

# %%
with open("blockbusters.json") as f:
    data = json.load(f)

# %%
data
# Out:
# [{'title': 'Avengers: Endgame',
#   'id': 299534,
#   'revenue': 2797800564,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 181},
#  {'title': 'Avatar',
#   'id': 19995,
#   'revenue': 2787965087,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/nslJVsO58Etqkk17oXMuVK4gNOF.jpg',
#    'backdrop_path': '/8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg'},
#   'runtime': 162},
#  {'title': 'Star Wars: The Force Awakens',
#   'id': 140607,
#   'revenue': 2068223624,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 136},
#  {'title': 'Avengers: Infinity War',
#   'id': 299536,
#   'revenue': 2046239637,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 149},
#  {'title': 'Titanic',
#   'id': 597,
#   'revenue': 1845034188,
#   'genres': [{'id': 18, 'name': 'Drama'},
#    {'id': 10749, 'name': 'Romance'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': None,
#   'runtime': 194},
#  {'title': 'Jurassic World',
#   'id': 135397,
#   'revenue': 1671713208,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 124},
#  {'title': 'The Lion King',
#   'id': 420818,
#   'revenue': 1656943394,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': None,
#   'runtime': 118},
#  {'title': 'The Avengers',
#   'id': 24428,
#   'revenue': 1519557910,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 143},
#  {'title': 'Furious 7',
#   'id': 168259,
#   'revenue': 1506249360,
#   'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}],
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/uv63yAGg1zETAs1XQsOQpava87l.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'runtime': 137},
#  {'title': 'Avengers: Age of Ultron',
#   'id': 99861,
#   'revenue': 1405403694,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'runtime': 141},
#  {'title': 'Black Panther',
#   'id': 284054,
#   'revenue': 1346739107,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg',
#    'backdrop_path': '/1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg'},
#   'runtime': 134},
#  {'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'id': 12445,
#   'revenue': 1341511219,
#   'genres': [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'},
#   'runtime': 130},
#  {'title': 'Star Wars: The Last Jedi',
#   'id': 181808,
#   'revenue': 1332539889,
#   'genres': [{'id': 14, 'name': 'Fantasy'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg',
#    'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#   'runtime': 152},
#  {'title': 'Frozen II',
#   'id': 330457,
#   'revenue': 1330764959,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 104},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'id': 351286,
#   'revenue': 1303459585,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'},
#   'runtime': 129},
#  {'title': 'Frozen',
#   'id': 109445,
#   'revenue': 1274219009,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/rpoXnE9UzCbjmINhxIi8bZF557B.jpg',
#    'backdrop_path': '/vZiqhw6oFoMlHSneIdVip9rRou2.jpg'},
#   'runtime': 102},
#  {'title': 'Beauty and the Beast',
#   'id': 321612,
#   'revenue': 1263521126,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'belongs_to_collection': None,
#   'runtime': 129},
#  {'title': 'Incredibles 2',
#   'id': 260513,
#   'revenue': 1241891456,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/l7GqbzkJwowYRIXAtUz2iCPi64a.jpg',
#    'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'},
#   'runtime': 118}]

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# {'title': 'Avengers: Endgame',
#  'id': 299534,
#  'revenue': 2797800564,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'}],
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'runtime': 181}

# %%
df = pd.read_json("blockbusters.json", orient = "record")
df
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                 belongs_to_collection  runtime
# 0   {'id': 86311, 'name': 'The Avengers Collection...      181
# 1   {'id': 87096, 'name': 'Avatar Collection', 'po...      162
# 2   {'id': 10, 'name': 'Star Wars Collection', 'po...      136
# 3   {'id': 86311, 'name': 'The Avengers Collection...      149
# 4                                                None      194
# 5   {'id': 328, 'name': 'Jurassic Park Collection'...      124
# 6                                                None      118
# 7   {'id': 86311, 'name': 'The Avengers Collection...      143
# 8   {'id': 9485, 'name': 'The Fast and the Furious...      137
# 9   {'id': 86311, 'name': 'The Avengers Collection...      141
# 10  {'id': 529892, 'name': 'Black Panther Collecti...      134
# 11  {'id': 1241, 'name': 'Harry Potter Collection'...      130
# 12  {'id': 10, 'name': 'Star Wars Collection', 'po...      152
# 13  {'id': 386382, 'name': 'Frozen Collection', 'p...      104
# 14  {'id': 328, 'name': 'Jurassic Park Collection'...      129
# 15  {'id': 386382, 'name': 'Frozen Collection', 'p...      102
# 16                                               None      129
# 17  {'id': 468222, 'name': 'The Incredibles Collec...      118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  18 non-null     object
#  1   id                     18 non-null     int64
#  2   revenue                18 non-null     int64
#  3   genres                 18 non-null     object
#  4   belongs_to_collection  15 non-null     object
#  5   runtime                18 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 992.0+ bytes

# %%
df.genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 86311,
#  'name': 'The Avengers Collection',
#  'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#  'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}

# %%
pd.json_normalize(data = data, sep = "_")
# Out:
#                                            title      id     revenue  \
# 0                              Avengers: Endgame  299534  2797800564
# 1                                         Avatar   19995  2787965087
# 2                   Star Wars: The Force Awakens  140607  2068223624
# 3                         Avengers: Infinity War  299536  2046239637
# 4                                        Titanic     597  1845034188
# 5                                 Jurassic World  135397  1671713208
# 6                                  The Lion King  420818  1656943394
# 7                                   The Avengers   24428  1519557910
# 8                                      Furious 7  168259  1506249360
# 9                        Avengers: Age of Ultron   99861  1405403694
# 10                                 Black Panther  284054  1346739107
# 11  Harry Potter and the Deathly Hallows: Part 2   12445  1341511219
# 12                      Star Wars: The Last Jedi  181808  1332539889
# 13                                     Frozen II  330457  1330764959
# 14                Jurassic World: Fallen Kingdom  351286  1303459585
# 15                                        Frozen  109445  1274219009
# 16                          Beauty and the Beast  321612  1263521126
# 17                                 Incredibles 2  260513  1241891456
#
#                                                genres  runtime  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      181
# 1   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      162
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      136
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      149
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      194
# 5   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      124
# 6   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...      118
# 7   [{'id': 878, 'name': 'Science Fiction'}, {'id'...      143
# 8   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      137
# 9   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      141
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      134
# 11  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      130
# 12  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...      152
# 13  [{'id': 16, 'name': 'Animation'}, {'id': 10751...      104
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      129
# 15  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      102
# 16  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...      129
# 17  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      118
#
#     belongs_to_collection_id           belongs_to_collection_name  \
# 0                    86311.0              The Avengers Collection
# 1                    87096.0                    Avatar Collection
# 2                       10.0                 Star Wars Collection
# 3                    86311.0              The Avengers Collection
# 4                        NaN                                  NaN
# 5                      328.0             Jurassic Park Collection
# 6                        NaN                                  NaN
# 7                    86311.0              The Avengers Collection
# 8                     9485.0  The Fast and the Furious Collection
# 9                    86311.0              The Avengers Collection
# 10                  529892.0             Black Panther Collection
# 11                    1241.0              Harry Potter Collection
# 12                      10.0                 Star Wars Collection
# 13                  386382.0                    Frozen Collection
# 14                     328.0             Jurassic Park Collection
# 15                  386382.0                    Frozen Collection
# 16                       NaN                                  NaN
# 17                  468222.0           The Incredibles Collection
#
#    belongs_to_collection_poster_path belongs_to_collection_backdrop_path  \
# 0   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 1   /nslJVsO58Etqkk17oXMuVK4gNOF.jpg    /8nCr9W7sKus2q9PLbYsnT7iCkuT.jpg
# 2   /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 3   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 4                                NaN                                 NaN
# 5   /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 6                                NaN                                 NaN
# 7   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 8   /uv63yAGg1zETAs1XQsOQpava87l.jpg    /z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg
# 9   /yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg    /zuW6fOiusv4X9nnW3paHGfXcSll.jpg
# 10  /9ZSPIsxI3TZDgfg0Jzk0RZl4INg.jpg    /1Jj7Frjjbewb6Q6dl6YXhL3kuvL.jpg
# 11  /eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg    /wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg
# 12  /iTQHKziZy9pAAY4hHEDCGPaOvFC.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 13  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 14  /qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg    /pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg
# 15  /rpoXnE9UzCbjmINhxIi8bZF557B.jpg    /vZiqhw6oFoMlHSneIdVip9rRou2.jpg
# 16                               NaN                                 NaN
# 17  /l7GqbzkJwowYRIXAtUz2iCPi64a.jpg    /9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg
#
#     belongs_to_collection
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN

# %%
pd.json_normalize(data = data, sep = "_").genres[0]
# Out:
# [{'id': 12, 'name': 'Adventure'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 28, 'name': 'Action'}]

# %%
pd.json_normalize(data = data, record_path = "genres", meta = ["title", "id"],
                  record_prefix = "genre_")
# Out:
#     genre_id       genre_name                                         title  \
# 0         12        Adventure                             Avengers: Endgame
# 1        878  Science Fiction                             Avengers: Endgame
# 2         28           Action                             Avengers: Endgame
# 3         28           Action                                        Avatar
# 4         12        Adventure                                        Avatar
# 5         14          Fantasy                                        Avatar
# 6        878  Science Fiction                                        Avatar
# 7         28           Action                  Star Wars: The Force Awakens
# 8         12        Adventure                  Star Wars: The Force Awakens
# 9        878  Science Fiction                  Star Wars: The Force Awakens
# 10        14          Fantasy                  Star Wars: The Force Awakens
# 11        12        Adventure                        Avengers: Infinity War
# 12        28           Action                        Avengers: Infinity War
# 13       878  Science Fiction                        Avengers: Infinity War
# 14        18            Drama                                       Titanic
# 15     10749          Romance                                       Titanic
# 16        53         Thriller                                       Titanic
# 17        28           Action                                Jurassic World
# 18        12        Adventure                                Jurassic World
# 19       878  Science Fiction                                Jurassic World
# 20        53         Thriller                                Jurassic World
# 21        12        Adventure                                 The Lion King
# 22     10751           Family                                 The Lion King
# 23       878  Science Fiction                                  The Avengers
# 24        28           Action                                  The Avengers
# 25        12        Adventure                                  The Avengers
# 26        28           Action                                     Furious 7
# 27        53         Thriller                                     Furious 7
# 28        28           Action                       Avengers: Age of Ultron
# 29        12        Adventure                       Avengers: Age of Ultron
# 30       878  Science Fiction                       Avengers: Age of Ultron
# 31        28           Action                                 Black Panther
# 32        12        Adventure                                 Black Panther
# 33        14          Fantasy                                 Black Panther
# 34       878  Science Fiction                                 Black Panther
# 35        14          Fantasy  Harry Potter and the Deathly Hallows: Part 2
# 36        12        Adventure  Harry Potter and the Deathly Hallows: Part 2
# 37        14          Fantasy                      Star Wars: The Last Jedi
# 38        12        Adventure                      Star Wars: The Last Jedi
# 39       878  Science Fiction                      Star Wars: The Last Jedi
# 40        28           Action                      Star Wars: The Last Jedi
# 41        16        Animation                                     Frozen II
# 42     10751           Family                                     Frozen II
# 43        12        Adventure                                     Frozen II
# 44        28           Action                Jurassic World: Fallen Kingdom
# 45        12        Adventure                Jurassic World: Fallen Kingdom
# 46       878  Science Fiction                Jurassic World: Fallen Kingdom
# 47        16        Animation                                        Frozen
# 48        12        Adventure                                        Frozen
# 49     10751           Family                                        Frozen
# 50     10751           Family                          Beauty and the Beast
# 51        14          Fantasy                          Beauty and the Beast
# 52     10749          Romance                          Beauty and the Beast
# 53        28           Action                                 Incredibles 2
# 54        12        Adventure                                 Incredibles 2
# 55        16        Animation                                 Incredibles 2
# 56     10751           Family                                 Incredibles 2
#
#         id
# 0   299534
# 1   299534
# 2   299534
# 3    19995
# 4    19995
# 5    19995
# 6    19995
# 7   140607
# 8   140607
# 9   140607
# 10  140607
# 11  299536
# 12  299536
# 13  299536
# 14     597
# 15     597
# 16     597
# 17  135397
# 18  135397
# 19  135397
# 20  135397
# 21  420818
# 22  420818
# 23   24428
# 24   24428
# 25   24428
# 26  168259
# 27  168259
# 28   99861
# 29   99861
# 30   99861
# 31  284054
# 32  284054
# 33  284054
# 34  284054
# 35   12445
# 36   12445
# 37  181808
# 38  181808
# 39  181808
# 40  181808
# 41  330457
# 42  330457
# 43  330457
# 44  351286
# 45  351286
# 46  351286
# 47  109445
# 48  109445
# 49  109445
# 50  321612
# 51  321612
# 52  321612
# 53  260513
# 54  260513
# 55  260513
# 56  260513

# %% [markdown]
# ## Working with APIs and JSON (Part 1)

# %%
api_key  = "api_key=abc123"

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
movie_id = 140607

# %%
movie_api = "https://api.themoviedb.org/3/movie/{}?"
movie_api
# Out:
# 'https://api.themoviedb.org/3/movie/{}?'

# %%
url = movie_api.format(movie_id) + api_key
url
# Out:
# 'https://api.themoviedb.org/3/movie/140607?api_key=a0651c6060a1ddc950880056e283e5f3'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'adult': False,
#  'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg',
#   'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'},
#  'budget': 245000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 878, 'name': 'Science Fiction'},
#   {'id': 14, 'name': 'Fantasy'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#  'id': 140607,
#  'imdb_id': 'tt2488496',
#  'original_language': 'en',
#  'original_title': 'Star Wars: The Force Awakens',
#  'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#  'popularity': 54.163,
#  'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#  'production_companies': [{'id': 1,
#    'logo_path': '/o86DbpburjxrqAzEDhXZcyE8pDb.png',
#    'name': 'Lucasfilm Ltd.',
#    'origin_country': 'US'},
#   {'id': 11461,
#    'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#    'name': 'Bad Robot',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2015-12-15',
#  'revenue': 2068223624,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Every generation has a story.',
#  'title': 'Star Wars: The Force Awakens',
#  'video': False,
#  'vote_average': 7.4,
#  'vote_count': 15506}

# %%
type(data)
# Out:
# dict

# %%
#pd.DataFrame(data)

# %%
pd.Series(data)
# Out:
# adult                                                                False
# backdrop_path                             /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# belongs_to_collection    {'id': 10, 'name': 'Star Wars Collection', 'po...
# budget                                                           245000000
# genres                   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# homepage                 http://www.starwars.com/films/star-wars-episod...
# id                                                                  140607
# imdb_id                                                          tt2488496
# original_language                                                       en
# original_title                                Star Wars: The Force Awakens
# overview                 Thirty years after defeating the Galactic Empi...
# popularity                                                          54.163
# poster_path                               /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# production_companies     [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    2015-12-15
# revenue                                                         2068223624
# runtime                                                                136
# spoken_languages         [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                            Released
# tagline                                      Every generation has a story.
# title                                         Star Wars: The Force Awakens
# video                                                                False
# vote_average                                                           7.4
# vote_count                                                           15506
# dtype: object

# %%
df = pd.Series(data).to_frame().T
df
# Out:
#    adult                     backdrop_path  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview popularity  \
# 0  Thirty years after defeating the Galactic Empi...     54.163
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#   runtime                                   spoken_languages    status  \
# 0     136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#   vote_average vote_count
# 0          7.4      15506

# %%
pd.json_normalize(data, sep = "_")
# Out:
#    adult                     backdrop_path     budget  \
# 0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg  245000000
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             homepage      id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
#
#   original_language                original_title  \
# 0                en  Star Wars: The Force Awakens
#
#                                             overview  popularity  \
# 0  Thirty years after defeating the Galactic Empi...      54.163
#
#                         poster_path  \
# 0  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
#
#                                 production_companies  \
# 0  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...
#
#                                 production_countries release_date     revenue  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15  2068223624
#
#    runtime                                   spoken_languages    status  \
# 0      136  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline                         title  video  \
# 0  Every generation has a story.  Star Wars: The Force Awakens  False
#
#    vote_average  vote_count  belongs_to_collection_id  \
# 0           7.4       15506                        10
#
#   belongs_to_collection_name belongs_to_collection_poster_path  \
# 0       Star Wars Collection  /r8Ph5MYXL04Qzu4QBbq2KjqwtkQ.jpg
#
#   belongs_to_collection_backdrop_path
# 0    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg

# %%
pd.json_normalize(data = data, record_path = "genres", meta = "title")
# Out:
#     id             name                         title
# 0   28           Action  Star Wars: The Force Awakens
# 1   12        Adventure  Star Wars: The Force Awakens
# 2  878  Science Fiction  Star Wars: The Force Awakens
# 3   14          Fantasy  Star Wars: The Force Awakens

# %%
pd.json_normalize(data = data, record_path = "production_companies", meta = "title")
# Out:
#       id                         logo_path            name origin_country  \
# 0      1  /o86DbpburjxrqAzEDhXZcyE8pDb.png  Lucasfilm Ltd.             US
# 1  11461  /p9FoEt5shEKRWRKVIlvFaEmRnun.png       Bad Robot             US
#
#                           title
# 0  Star Wars: The Force Awakens
# 1  Star Wars: The Force Awakens

# %% [markdown]
# ## Working with APIs and JSON (Part 2)

# %%
import pandas as pd
import requests
pd.options.display.max_columns = 30

# %%
discover_api = "https://api.themoviedb.org/3/discover/movie?"

# %%
query = "&primary_release_date.gte=2020-01-01&primary_release_date.lte=2020-02-29"

# %%
url = discover_api+api_key+query

# %%
data = requests.get(url).json()

# %%
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/9xNOiv6DZZjH7ABoUUDP0ZynouU.jpg',
#    'genre_ids': [28, 80],
#    'id': 495764,
#    'original_language': 'en',
#    'original_title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'overview': 'Harley Quinn joins forces with a singer, an assassin and a police detective to help a young girl who had a hit placed on her after she stole a rare diamond from a crime lord.',
#    'popularity': 577.638,
#    'poster_path': '/h4VB6m0RwcicVEZvzftYZyKXs6K.jpg',
#    'release_date': '2020-02-05',
#    'title': 'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 6919},
#   {'adult': False,
#    'backdrop_path': '/upUy2QhMZEmtypPW3PdieKLAHxh.jpg',
#    'genre_ids': [53, 28, 80],
#    'id': 38700,
#    'original_language': 'en',
#    'original_title': 'Bad Boys for Life',
#    'overview': 'Marcus and Mike are forced to confront new threats, career changes, and midlife crises as they join the newly created elite team AMMO of the Miami police department to take down the ruthless Armando Armas, the vicious leader of a Miami drug cartel.',
#    'popularity': 410.189,
#    'poster_path': '/y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg',
#    'release_date': '2020-01-15',
#    'title': 'Bad Boys for Life',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 5983},
#   {'adult': False,
#    'backdrop_path': '/5VKquU8PNujrxLmsYGHf2TCRNFQ.jpg',
#    'genre_ids': [878, 28, 12, 9648, 36, 14],
#    'id': 582306,
#    'original_language': 'en',
#    'original_title': 'Assassin 33 A.D.',
#    'overview': 'When a billionaire gives a group of young scientists unlimited resources to study the science of matter transfer, the scientists unlock the secrets of time travel. But they soon find out that the project is backed by a militant extremist group, and the billionaire plans to go back in time and prove that Jesus never rose from the dead.',
#    'popularity': 337.353,
#    'poster_path': '/8jDvtdH327I8TgX3UPdkAsZF1dA.jpg',
#    'release_date': '2020-01-24',
#    'title': 'Assassin 33 A.D.',
#    'video': False,
#    'vote_average': 5.3,
#    'vote_count': 25},
#   {'adult': False,
#    'backdrop_path': '/6mKAKhj8POVGqV1GsroS5mGIUe9.jpg',
#    'genre_ids': [14, 28, 12],
#    'id': 666750,
#    'original_language': 'en',
#    'original_title': 'Dragonheart: Vengeance',
#    'overview': 'Lukas, a young farmer whose family is killed by savage raiders in the countryside, sets out on an epic quest for revenge, forming an unlikely trio with a majestic dragon and a swashbuckling, sword-fighting mercenary, Darius.',
#    'popularity': 324.201,
#    'poster_path': '/qs6gz6atyQcAvqC6qZaslOjliUG.jpg',
#    'release_date': '2020-02-04',
#    'title': 'Dragonheart: Vengeance',
#    'video': False,
#    'vote_average': 6.8,
#    'vote_count': 196},
#   {'adult': False,
#    'backdrop_path': '/ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg',
#    'genre_ids': [28, 27, 878, 53],
#    'id': 443791,
#    'original_language': 'en',
#    'original_title': 'Underwater',
#    'overview': 'After an earthquake destroys their underwater station, six researchers must navigate two miles along the dangerous, unknown depths of the ocean floor to make it to safety in a race against time.',
#    'popularity': 239.835,
#    'poster_path': '/gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg',
#    'release_date': '2020-01-08',
#    'title': 'Underwater',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 1918},
#   {'adult': False,
#    'backdrop_path': '/9LsJP9OuIBmBUxZpmVKtUUjF0PA.jpg',
#    'genre_ids': [10749, 35],
#    'id': 565426,
#    'original_language': 'en',
#    'original_title': 'To All the Boys: P.S. I Still Love You',
#    'overview': 'Lara Jean and Peter have just taken their romance from pretend to officially real when another recipient of one of her love letters enters the picture.',
#    'popularity': 214.001,
#    'poster_path': '/maib5VlmEqp5xlN8lptnBSftp2o.jpg',
#    'release_date': '2020-02-12',
#    'title': 'To All the Boys: P.S. I Still Love You',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 1791},
#   {'adult': False,
#    'backdrop_path': '/4br4B8C0SRIYcKHUgoaOlGo50MU.jpg',
#    'genre_ids': [27],
#    'id': 575088,
#    'original_language': 'ru',
#    'original_title': 'Яга. Кошмар тёмного леса',
#    'overview': 'The young family who moved to a new apartment on the outskirts of the city. The nanny hired by them for the newborn daughter quickly gained confidence. However, the older boy, Egor, talks about the frightening behavior of a woman, but his parents do not believe him. The surveillance cameras installed by the father for comfort only confirm everything is in order. Then one day, Egor, returning home, finds no trace of either the nanny or the little sister, and the parents are in a strange trance and do not even remember that they had a daughter. Then Egor, together with his friends, goes in search, during which it turns out that the nanny is an ancient Slavic demon, popularly known as Baba Yaga.',
#    'popularity': 230.245,
#    'poster_path': '/8m5HTXzwewlfXhtZtLlLts53YTW.jpg',
#    'release_date': '2020-02-27',
#    'title': 'Baba Yaga: Terror of the Dark Forest',
#    'video': False,
#    'vote_average': 6.5,
#    'vote_count': 84},
#   {'adult': False,
#    'backdrop_path': '/sCtJkYwBrJm8mygRrDGyluf1gSV.jpg',
#    'genre_ids': [27, 878, 53],
#    'id': 736509,
#    'original_language': 'en',
#    'original_title': 'Intersect',
#    'overview': 'A group of young Miskatonic University scientists invent a time machine, only to learn that they are being manipulated by mysterious, unseen forces from another dimension.',
#    'popularity': 210.443,
#    'poster_path': '/e6hgmD0P133bW5EH1kfhscwXN2a.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Intersect',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 24},
#   {'adult': False,
#    'backdrop_path': '/dT05ycGuf4h1uYYAJttxTFKkfBQ.jpg',
#    'genre_ids': [10752, 18],
#    'id': 662334,
#    'original_language': 'es',
#    'original_title': 'Chaco',
#    'overview': "In 1934, Bolivia is at war with Paraguay. Liborio and Ticona and other Bolivian indigenous soldiers are lost in the hell of the Chaco, under the commandment of German Captain Kundt. They're looking for the Paraguayan enemy that they haven't seen for months, and that they will never find. They leave together in a search that will make them realize, progressively, the destiny they have been pushed into and the inevitable condition of a defeated troop. They're walking like shadows, wandering forever in the middle of dust and silence.",
#    'popularity': 214.629,
#    'poster_path': '/hCR2i9rK6P4VHMfFw2MT5jDGJcN.jpg',
#    'release_date': '2020-01-28',
#    'title': 'Chaco',
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 40},
#   {'adult': False,
#    'backdrop_path': '/a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg',
#    'genre_ids': [18, 28, 53],
#    'id': 571785,
#    'original_language': 'ko',
#    'original_title': '사냥의 시간',
#    'overview': 'Four young men who want to leave their dystopian world behind and go to a distant paradise execute a money robbery, a daring act that will have unexpected consequences.',
#    'popularity': 222.481,
#    'poster_path': '/bkuuvDoPkOJpg0ZDzHkUWt8ZG5A.jpg',
#    'release_date': '2020-02-22',
#    'title': 'Time to Hunt',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 164},
#   {'adult': False,
#    'backdrop_path': '/lsgYcIbcoQeDZXsHYMOnkvk3sn0.jpg',
#    'genre_ids': [18, 53],
#    'id': 505225,
#    'original_language': 'en',
#    'original_title': 'The Last Thing He Wanted',
#    'overview': 'At the turning point of the Iran-Contra affair, Elena McMahon, a fearless investigative journalist covering the 1984 US presidential campaign, puts herself in danger when she abandons her assigned task in order to fulfill the last wish of her ailing father, a mysterious man whose past activities she barely knows.',
#    'popularity': 219.873,
#    'poster_path': '/gItrnbEbMBbUrdIkFz8kgS2gkt.jpg',
#    'release_date': '2020-02-14',
#    'title': 'The Last Thing He Wanted',
#    'video': False,
#    'vote_average': 4.9,
#    'vote_count': 297},
#   {'adult': False,
#    'backdrop_path': '/p6ExERRwodksg0fFKzCjmNCR6Hw.jpg',
#    'genre_ids': [53],
#    'id': 531299,
#    'original_language': 'en',
#    'original_title': 'Kill Chain',
#    'overview': 'A hotel room shootout between two assassins kicks off a long night where bodies fall like dominoes, as we follow a chain of crooked cops, gangsters, hitmen, a femme Fatale and an ex-mercenary through a relay of murder, betrayal, revenge and redemption.',
#    'popularity': 190.94,
#    'poster_path': '/wy0Xs5mGtD92PyKvsl0lxzbzscG.jpg',
#    'release_date': '2020-02-20',
#    'title': 'Kill Chain',
#    'video': False,
#    'vote_average': 5.5,
#    'vote_count': 60},
#   {'adult': False,
#    'backdrop_path': '/ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg',
#    'genre_ids': [16, 12, 28, 14],
#    'id': 631132,
#    'original_language': 'ja',
#    'original_title': "ゴブリンスレイヤー -GOBLIN'S CROWN-",
#    'overview': 'Goblin Slayer and his party head up to the snowy mountains in the north after receiving that request from the Sword Maiden to find any information on the Noble Fencer that disappeared after leaving to slay some goblins. A small village gets attacked, they encounter a mysterious chapel, and something about how these goblins are acting bothers the Goblin slayer.  In order to save the captured Noble Fencer, the Goblin Slayer and his party head to an ancient fortress covered in snow to face off with a powerful foe and a horde of goblins!',
#    'popularity': 192.735,
#    'poster_path': '/oyDaF4za9C9GxfYSyZUmj2aZGJT.jpg',
#    'release_date': '2020-02-01',
#    'title': "Goblin Slayer: Goblin's Crown",
#    'video': False,
#    'vote_average': 7.9,
#    'vote_count': 94},
#   {'adult': False,
#    'backdrop_path': '/xRKwiUHGnsZGxZaO6OIKqpzJjPa.jpg',
#    'genre_ids': [28, 53],
#    'id': 466622,
#    'original_language': 'en',
#    'original_title': 'The Rhythm Section',
#    'overview': 'After the death of her family in an airplane crash on a flight that she was meant to be on, Stephanie Patrick discovers the crash was not an accident. She then seeks to uncover the truth by adapting the identity of an assassin to track down those responsible.',
#    'popularity': 185.582,
#    'poster_path': '/spTr0VYyRtl36Lkk6nCnnbFXhus.jpg',
#    'release_date': '2020-01-31',
#    'title': 'The Rhythm Section',
#    'video': False,
#    'vote_average': 5.6,
#    'vote_count': 314},
#   {'adult': False,
#    'backdrop_path': '/1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg',
#    'genre_ids': [35, 53, 80],
#    'id': 609242,
#    'original_language': 'es',
#    'original_title': 'El robo del siglo',
#    'overview': 'In 2006, a group of thieves performed what is considered one of the most famous and smart bank heists in the history of Argentina. How they robbed the Rio bank is as surprising as what happened afterwards. This is their story.',
#    'popularity': 146.126,
#    'poster_path': '/xdKJ6LdA65RFxjNYIL8fV89Tv0d.jpg',
#    'release_date': '2020-01-16',
#    'title': 'The Heist of the Century',
#    'video': False,
#    'vote_average': 8,
#    'vote_count': 464},
#   {'adult': False,
#    'backdrop_path': '/stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg',
#    'genre_ids': [28, 878, 35, 10751],
#    'id': 454626,
#    'original_language': 'en',
#    'original_title': 'Sonic the Hedgehog',
#    'overview': 'Based on the global blockbuster videogame franchise from Sega, Sonic the Hedgehog tells the story of the world’s speediest hedgehog as he embraces his new home on Earth. In this live-action adventure comedy, Sonic and his new best friend team up to defend the planet from the evil genius Dr. Robotnik and his plans for world domination.',
#    'popularity': 115.501,
#    'poster_path': '/aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg',
#    'release_date': '2020-02-12',
#    'title': 'Sonic the Hedgehog',
#    'video': False,
#    'vote_average': 7.5,
#    'vote_count': 6533},
#   {'adult': False,
#    'backdrop_path': '/dyvN0x7kjfadYGDszWi18llr1ZY.jpg',
#    'genre_ids': [35],
#    'id': 623926,
#    'original_language': 'es',
#    'original_title': 'Hasta que la boda nos separe',
#    'overview': 'Marina is a woman in her thirties who works organizing weddings. Not because she is an inveterate romantic just because, as she says, "when people are in love, they don\'t care about money". Unlike her customers, she enjoys a life without ties or commitments, until the moment when she falls in love with Carlos. The problem is not only he is about to get married, but also his fiancee is Marina\'s childhood friend and they have hired her as their Wedding Planner.',
#    'popularity': 128.222,
#    'poster_path': '/bkz7ZoqJMFziqF8yQzkmfMRUEG.jpg',
#    'release_date': '2020-02-14',
#    'title': 'The Wedding Unplanner',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 100},
#   {'adult': False,
#    'backdrop_path': '/iOGxpQtUrjs9WBze13jzAq2ZLD.jpg',
#    'genre_ids': [28, 35],
#    'id': 591237,
#    'original_language': 'en',
#    'original_title': 'Bulletproof 2',
#    'overview': 'Special Agent Jack Carter reluctantly assumes the identity of criminal Archie Moses to take down a powerful South African crime family. But when the real Moses is put in danger, he and Carter must work together to foil the scheme for good.',
#    'popularity': 127.513,
#    'poster_path': '/uGILkFnRrpdiNtDaHeekGZSn5o5.jpg',
#    'release_date': '2020-01-07',
#    'title': 'Bulletproof 2',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 66},
#   {'adult': False,
#    'backdrop_path': '/ebKa6nCRkKWU3KIuacEkEe6XSQl.jpg',
#    'genre_ids': [35],
#    'id': 610461,
#    'original_language': 'es',
#    'original_title': 'Veinteañera, divorciada y fantástica',
#    'overview': 'Regina, our young protagonist, always dreamed of getting married. And she did it - but the dream lasted much less than she thought and now she has to face life in a very funny way as a divorcee.',
#    'popularity': 110.261,
#    'poster_path': '/wpC0bIYYfAY0wLa8sjlzIspMQr4.jpg',
#    'release_date': '2020-02-14',
#    'title': 'Veinteañera, divorciada y fantástica',
#    'video': False,
#    'vote_average': 8.2,
#    'vote_count': 303},
#   {'adult': False,
#    'backdrop_path': '/aBvw8qYDMmbyU4ttzWSfiTxeICG.jpg',
#    'genre_ids': [35],
#    'id': 557940,
#    'original_language': 'es',
#    'original_title': 'Las Pildoras de mi Novio',
#    'overview': "A Woman's island getaway with her boyfriend is thrown for a loop when he forgets to take his prescription medications along.",
#    'popularity': 100.583,
#    'poster_path': '/hVSOXCBuPXw8yXqbNfwU9ogIp88.jpg',
#    'release_date': '2020-02-14',
#    'title': "My Boyfriend's Meds",
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 264}],
#  'total_pages': 185,
#  'total_results': 3696}

# %%
pd.DataFrame(data)
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/9xNOiv6DZZ...          185
# 1      1  {'adult': False, 'backdrop_path': '/upUy2QhMZE...          185
# 2      1  {'adult': False, 'backdrop_path': '/5VKquU8PNu...          185
# 3      1  {'adult': False, 'backdrop_path': '/6mKAKhj8PO...          185
# 4      1  {'adult': False, 'backdrop_path': '/ww7eC3BqSb...          185
# 5      1  {'adult': False, 'backdrop_path': '/9LsJP9OuIB...          185
# 6      1  {'adult': False, 'backdrop_path': '/4br4B8C0SR...          185
# 7      1  {'adult': False, 'backdrop_path': '/sCtJkYwBrJ...          185
# 8      1  {'adult': False, 'backdrop_path': '/dT05ycGuf4...          185
# 9      1  {'adult': False, 'backdrop_path': '/a8ppJJIQmE...          185
# 10     1  {'adult': False, 'backdrop_path': '/lsgYcIbcoQ...          185
# 11     1  {'adult': False, 'backdrop_path': '/p6ExERRwod...          185
# 12     1  {'adult': False, 'backdrop_path': '/ySHlkHDbXz...          185
# 13     1  {'adult': False, 'backdrop_path': '/xRKwiUHGns...          185
# 14     1  {'adult': False, 'backdrop_path': '/1umKVgbjFG...          185
# 15     1  {'adult': False, 'backdrop_path': '/stmYfCUGd8...          185
# 16     1  {'adult': False, 'backdrop_path': '/dyvN0x7kjf...          185
# 17     1  {'adult': False, 'backdrop_path': '/iOGxpQtUrj...          185
# 18     1  {'adult': False, 'backdrop_path': '/ebKa6nCRkK...          185
# 19     1  {'adult': False, 'backdrop_path': '/aBvw8qYDMm...          185
#
#     total_results
# 0            3696
# 1            3696
# 2            3696
# 3            3696
# 4            3696
# 5            3696
# 6            3696
# 7            3696
# 8            3696
# 9            3696
# 10           3696
# 11           3696
# 12           3696
# 13           3696
# 14           3696
# 15           3696
# 16           3696
# 17           3696
# 18           3696
# 19           3696

# %%
pd.DataFrame(data["results"])
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False  /9xNOiv6DZZjH7ABoUUDP0ZynouU.jpg                     [28, 80]
# 1   False  /upUy2QhMZEmtypPW3PdieKLAHxh.jpg                 [53, 28, 80]
# 2   False  /5VKquU8PNujrxLmsYGHf2TCRNFQ.jpg  [878, 28, 12, 9648, 36, 14]
# 3   False  /6mKAKhj8POVGqV1GsroS5mGIUe9.jpg                 [14, 28, 12]
# 4   False  /ww7eC3BqSbFsyE5H5qMde8WkxJ2.jpg            [28, 27, 878, 53]
# 5   False  /9LsJP9OuIBmBUxZpmVKtUUjF0PA.jpg                  [10749, 35]
# 6   False  /4br4B8C0SRIYcKHUgoaOlGo50MU.jpg                         [27]
# 7   False  /sCtJkYwBrJm8mygRrDGyluf1gSV.jpg                [27, 878, 53]
# 8   False  /dT05ycGuf4h1uYYAJttxTFKkfBQ.jpg                  [10752, 18]
# 9   False  /a8ppJJIQmEJcLSFfhxupc4aT4KW.jpg                 [18, 28, 53]
# 10  False  /lsgYcIbcoQeDZXsHYMOnkvk3sn0.jpg                     [18, 53]
# 11  False  /p6ExERRwodksg0fFKzCjmNCR6Hw.jpg                         [53]
# 12  False  /ySHlkHDbXztjdjRJ0pZN7FXRnaW.jpg             [16, 12, 28, 14]
# 13  False  /xRKwiUHGnsZGxZaO6OIKqpzJjPa.jpg                     [28, 53]
# 14  False  /1umKVgbjFG5Cho5ZKTpcvRFJjuJ.jpg                 [35, 53, 80]
# 15  False  /stmYfCUGd8Iy6kAMBr6AmWqx8Bq.jpg         [28, 878, 35, 10751]
# 16  False  /dyvN0x7kjfadYGDszWi18llr1ZY.jpg                         [35]
# 17  False   /iOGxpQtUrjs9WBze13jzAq2ZLD.jpg                     [28, 35]
# 18  False  /ebKa6nCRkKWU3KIuacEkEe6XSQl.jpg                         [35]
# 19  False  /aBvw8qYDMmbyU4ttzWSfiTxeICG.jpg                         [35]
#
#         id original_language  \
# 0   495764                en
# 1    38700                en
# 2   582306                en
# 3   666750                en
# 4   443791                en
# 5   565426                en
# 6   575088                ru
# 7   736509                en
# 8   662334                es
# 9   571785                ko
# 10  505225                en
# 11  531299                en
# 12  631132                ja
# 13  466622                en
# 14  609242                es
# 15  454626                en
# 16  623926                es
# 17  591237                en
# 18  610461                es
# 19  557940                es
#
#                                        original_title  \
# 0   Birds of Prey (and the Fantabulous Emancipatio...
# 1                                   Bad Boys for Life
# 2                                    Assassin 33 A.D.
# 3                              Dragonheart: Vengeance
# 4                                          Underwater
# 5              To All the Boys: P.S. I Still Love You
# 6                            Яга. Кошмар тёмного леса
# 7                                           Intersect
# 8                                               Chaco
# 9                                              사냥의 시간
# 10                           The Last Thing He Wanted
# 11                                         Kill Chain
# 12                         ゴブリンスレイヤー -GOBLIN'S CROWN-
# 13                                 The Rhythm Section
# 14                                  El robo del siglo
# 15                                 Sonic the Hedgehog
# 16                       Hasta que la boda nos separe
# 17                                      Bulletproof 2
# 18               Veinteañera, divorciada y fantástica
# 19                           Las Pildoras de mi Novio
#
#                                              overview  popularity  \
# 0   Harley Quinn joins forces with a singer, an as...     577.638
# 1   Marcus and Mike are forced to confront new thr...     410.189
# 2   When a billionaire gives a group of young scie...     337.353
# 3   Lukas, a young farmer whose family is killed b...     324.201
# 4   After an earthquake destroys their underwater ...     239.835
# 5   Lara Jean and Peter have just taken their roma...     214.001
# 6   The young family who moved to a new apartment ...     230.245
# 7   A group of young Miskatonic University scienti...     210.443
# 8   In 1934, Bolivia is at war with Paraguay. Libo...     214.629
# 9   Four young men who want to leave their dystopi...     222.481
# 10  At the turning point of the Iran-Contra affair...     219.873
# 11  A hotel room shootout between two assassins ki...     190.940
# 12  Goblin Slayer and his party head up to the sno...     192.735
# 13  After the death of her family in an airplane c...     185.582
# 14  In 2006, a group of thieves performed what is ...     146.126
# 15  Based on the global blockbuster videogame fran...     115.501
# 16  Marina is a woman in her thirties who works or...     128.222
# 17  Special Agent Jack Carter reluctantly assumes ...     127.513
# 18  Regina, our young protagonist, always dreamed ...     110.261
# 19  A Woman's island getaway with her boyfriend is...     100.583
#
#                          poster_path release_date  \
# 0   /h4VB6m0RwcicVEZvzftYZyKXs6K.jpg   2020-02-05
# 1   /y95lQLnuNKdPAzw9F9Ab8kJ80c3.jpg   2020-01-15
# 2   /8jDvtdH327I8TgX3UPdkAsZF1dA.jpg   2020-01-24
# 3   /qs6gz6atyQcAvqC6qZaslOjliUG.jpg   2020-02-04
# 4   /gzlbb3yeVISpQ3REd3Ga1scWGTU.jpg   2020-01-08
# 5   /maib5VlmEqp5xlN8lptnBSftp2o.jpg   2020-02-12
# 6   /8m5HTXzwewlfXhtZtLlLts53YTW.jpg   2020-02-27
# 7   /e6hgmD0P133bW5EH1kfhscwXN2a.jpg   2020-02-12
# 8   /hCR2i9rK6P4VHMfFw2MT5jDGJcN.jpg   2020-01-28
# 9   /bkuuvDoPkOJpg0ZDzHkUWt8ZG5A.jpg   2020-02-22
# 10   /gItrnbEbMBbUrdIkFz8kgS2gkt.jpg   2020-02-14
# 11  /wy0Xs5mGtD92PyKvsl0lxzbzscG.jpg   2020-02-20
# 12  /oyDaF4za9C9GxfYSyZUmj2aZGJT.jpg   2020-02-01
# 13  /spTr0VYyRtl36Lkk6nCnnbFXhus.jpg   2020-01-31
# 14  /xdKJ6LdA65RFxjNYIL8fV89Tv0d.jpg   2020-01-16
# 15  /aQvJ5WPzZgYVDrxLX4R6cLJCEaQ.jpg   2020-02-12
# 16   /bkz7ZoqJMFziqF8yQzkmfMRUEG.jpg   2020-02-14
# 17  /uGILkFnRrpdiNtDaHeekGZSn5o5.jpg   2020-01-07
# 18  /wpC0bIYYfAY0wLa8sjlzIspMQr4.jpg   2020-02-14
# 19  /hVSOXCBuPXw8yXqbNfwU9ogIp88.jpg   2020-02-14
#
#                                                 title  video  vote_average  \
# 0   Birds of Prey (and the Fantabulous Emancipatio...  False           7.1
# 1                                   Bad Boys for Life  False           7.2
# 2                                    Assassin 33 A.D.  False           5.3
# 3                              Dragonheart: Vengeance  False           6.8
# 4                                          Underwater  False           6.3
# 5              To All the Boys: P.S. I Still Love You  False           6.9
# 6                Baba Yaga: Terror of the Dark Forest  False           6.5
# 7                                           Intersect  False           5.8
# 8                                               Chaco  False           7.9
# 9                                        Time to Hunt  False           7.2
# 10                           The Last Thing He Wanted  False           4.9
# 11                                         Kill Chain  False           5.5
# 12                      Goblin Slayer: Goblin's Crown  False           7.9
# 13                                 The Rhythm Section  False           5.6
# 14                           The Heist of the Century  False           8.0
# 15                                 Sonic the Hedgehog  False           7.5
# 16                              The Wedding Unplanner  False           6.9
# 17                                      Bulletproof 2  False           7.2
# 18               Veinteañera, divorciada y fantástica  False           8.2
# 19                                My Boyfriend's Meds  False           7.2
#
#     vote_count
# 0         6919
# 1         5983
# 2           25
# 3          196
# 4         1918
# 5         1791
# 6           84
# 7           24
# 8           40
# 9          164
# 10         297
# 11          60
# 12          94
# 13         314
# 14         464
# 15        6533
# 16         100
# 17          66
# 18         303
# 19         264

# %% [markdown]
# ##  Importing and Saving the Movies Dataset (Best Practice)

# %%
import pandas as pd
import requests
import json
pd.options.display.max_columns = 30

# %%
movie_id = [0, 299534, 19995, 140607, 299536, 597, 135397,
            420818, 24428, 168259, 99861, 284054, 12445,
            181808, 330457, 351286, 109445, 321612, 260513]

# %%
basic_url = 'https://api.themoviedb.org/3/movie/{}?{}'

# %%
json_list = []
for movie in movie_id:
    url = basic_url.format(movie, api_key)
    r = requests.get(url)
    if r.status_code != 200:
        continue
    else:
        data = r.json()
        json_list.append(data) 
df = pd.DataFrame(json_list)

# %%
requests.get(basic_url.format(0, api_key)).status_code

# %%
df

# %%
df = df.loc[:, ["title", "id", "revenue", "genres", "belongs_to_collection", "runtime"]].sort_values(by = "revenue",
                                                                                                ascending = False)

# %%
df

# %%
df.to_json("movies.json", orient = "records")

# %%
with open("movies.json") as f:
    data = json.load(f)

# %%
pd.json_normalize(data)

# %%
pd.json_normalize(data, "genres", "title")

# %% [markdown]
# # Importing and Saving the Movies Dataset (Real World Scenario)

# %%
df

# %%
df.to_csv("movies_raw.csv", index = False)

# %%
df = pd.read_csv("movies_raw.csv")

# %%
df

# %%
df.genres[0]
